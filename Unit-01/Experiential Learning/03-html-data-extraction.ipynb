# %%
from bs4 import BeautifulSoup

# %%
file_path = r"C:/Users/vaibh/Desktop/Coding/MCA SEM III/Natural Language Processing and Computer Vision/Unit-01/Experiential Learning/data/background.html"

with open(file_path, "r", encoding="utf-8") as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, "html.parser")

# %%
text = ''
for paragraph in soup.find_all('p'):
    text += paragraph.get_text() + '\n'

# %%
print(text)
# Out:
# Orange Box (#ff5733)
# Green Box (rgb(0, 128, 0))
# Yellow Box (yellow)
