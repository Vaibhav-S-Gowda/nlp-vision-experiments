# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.stem import LancasterStemmer

# %%
text = "Lemmatization important language technique. " \
       "Caring is Paring"

# %%
tokens = word_tokenize(text)

# %%
porter = PorterStemmer()
snowball = SnowballStemmer(language='english')
lancaster = LancasterStemmer()

print("{0:16} {1:16} {2:18} {3:18}".
     format("Word", "Porter", "Snowball", "Lancaster"))
for w in tokens:
    print("{0:16}{1:16}{2:18}{3:18}".
        format(w,porter.stem(w),snowball.stem(w),lancaster.stem(w)))
# Out:
# Word             Porter           Snowball           Lancaster
# Lemmatization   lemmat          lemmat            lem
# important       import          import            import
# language        languag         languag           langu
# technique       techniqu        techniqu          techn
# .               .               .                 .
# Caring          care            care              car
# is              is              is                is
# Paring          pare            pare              par

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True

# %%
from nltk.corpus import brown

categories = brown.categories()
print("\nCategories: ", categories)
# Out:
# Categories:  ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']

# %%
all_words = brown.words()
print("\nFirst 10 words: ", all_words[:10])
# Out:
# First 10 words:  ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of']

# %%
news_words = brown.words(categories="news")
print("\nFirst 10 words in news: ", news_words[:10])
# Out:
# First 10 words in news:  ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of']

# %%
all_sentences = brown.sents()
print("\nFirst sentence: ", ' '.join(all_sentences[00]))
# Out:
# First sentence:  The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .

# %%
news_sentences = brown.sents(categories='news')
print("\nFirst sentence in news: ", ' '.join(news_sentences[00]))
# Out:
# First sentence in news:  The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .
