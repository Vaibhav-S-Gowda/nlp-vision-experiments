# %%
import pandas as pd

df = pd.read_excel("C:/Users/vaibh/Desktop/Coding/MCA SEM III/Natural Language Processing and Computer Vision/Unit-01/Experiential Learning/data/people_records_20.xlsx")
print(df.head())
# Out:
#    Sl.No          Name   Birthday                     Email
# 0      1  Aarav Sharma 2001-03-14  aarav.sharma@example.com
# 1      2    Ananya Rao 2000-07-22    ananya.rao@example.com
# 2      3   Arjun Mehta 2002-01-09   arjun.mehta@example.com
# 3      4     Diya Nair 2001-11-05     diya.nair@example.com
# 4      5   Rohan Gupta 1999-05-18   rohan.gupta@example.com

# %%
import spacy
import re

# %%
nlp = spacy.blank("en")

email = "virat@kholi.com"

tokens = re.findall(r'\w+|@|\.', email)

print(tokens)
# Out:
# ['virat', '@', 'kholi', '.', 'com']
